# %%
#!:bash

# download and unzip dataset
wget http://cs231n.stanford.edu/tiny-imagenet-200.zip
unzip tiny-imagenet-200.zip

current="$(pwd)/tiny-imagenet-200"

# training data
cd $current/train
for DIR in $(ls); do
   cd $DIR
   rm *.txt
   mv images/* .
   rm -r images
   cd ..
done

# validation data
cd $current/val
annotate_file="val_annotations.txt"
length=$(cat $annotate_file | wc -l)
for i in $(seq 1 $length); do
    # fetch i th line
    line=$(sed -n ${i}p $annotate_file)
    # get file name and directory name
    file=$(echo $line | cut -f1 -d" " )
    directory=$(echo $line | cut -f2 -d" ")
    mkdir -p $directory
    mv images/$file $directory
done
rm -r images
echo "done"
# Out:
# ges/val_9901.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5814.JPEG
#   inflating: tiny-imagenet-200/val/images/val_8855.JPEG
#   inflating: tiny-imagenet-200/val/images/val_8860.JPEG
#   inflating: tiny-imagenet-200/val/images/val_3616.JPEG
#   inflating: tiny-imagenet-200/val/images/val_532.JPEG
#   inflating: tiny-imagenet-200/val/images/val_8686.JPEG
#   inflating: tiny-imagenet-200/val/images/val_2576.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5669.JPEG
#   inflating: tiny-imagenet-200/val/images/val_4449.JPEG
#   inflating: tiny-imagenet-200/val/images/val_4849.JPEG
#   inflating: tiny-imagenet-200/val/images/val_1535.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6354.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9034.JPEG
#   inflating: tiny-imagenet-200/val/images/val_2513.JPEG
#   inflating: tiny-imagenet-200/val/images/val_1948.JPEG
#   inflating: tiny-imagenet-200/val/images/val_4162.JPEG
# ...

# %%
#!g1.1
# !git add tini-imagenet.ipynb

# %%
#!g1.1
# !git config --global user.email "max.kvant@gmail.com"
# !git config --global user.name "maxkvant"

# %%
#!g1.1
# !git commit -m "boosting & zca on tini-imagenet"
# Out:
# [master 4315596] boosting & zca on tini-imagenet
#  1 file changed, 1 insertion(+)
#  create mode 100755 notebooks/tini-imagenet.ipynb

# %%
#!g1.1
# !git push --help
# Out:
# ...
# fatal: no man viewer handled the request
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-11-827e3715ea19> in <module>
# ----> 1 get_ipython().system('git push --help')
#       2 #
#
# /kernel/lib/python3.7/site-packages/ml_kernel/kernel.py in <lambda>(code)
#     259
#     260         self._script_executor = ScriptExecutor(ProcessHandler().system)
# --> 261         self.shell.system = lambda code: self._script_executor.execute("bash", code)
#     262
#     263     def _init_message_handlers(self):
#
# /kernel/lib/python3.7/site-packages/ml_kernel/script_executor.py in execute(self, lang, code)
#      33         return_code = self._system(code)
#      34         if return_code != 0:
# ---> 35             raise Exception('Process exited with code %d' % return_code)
#
# Exception: Process exited with code 128

# %%
#!g1.1
# !git remote set-url origin https://maxkvant:Uotheth7@github.com/maxkvant/LinearizedNNs

# %%
#!g1.1
# !git push
# Out:
# Counting objects: 4, done.
# Delta compression using up to 8 threads.
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 10.66 KiB | 2.66 MiB/s, done.
# Total 4 (delta 2), reused 0 (delta 0)
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To https://github.com/maxkvant/LinearizedNNs
#    b24129c..4315596  master -> master
