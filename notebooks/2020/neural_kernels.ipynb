# %%
import os
import shutil
import zipfile
import urllib.request


def download_repo(url, save_to):
    zip_filename = save_to + '.zip'
    urllib.request.urlretrieve(url, zip_filename)
    
    if os.path.exists(save_to):
        shutil.rmtree(save_to)
    with zipfile.ZipFile(zip_filename, 'r') as zip_ref:
        zip_ref.extractall('.')
    del zip_ref
    assert os.path.exists(save_to)

# %%
REPO_PATH = 'LinearizedNNs-master'

download_repo(url='https://github.com/maxkvant/LinearizedNNs/archive/master.zip',
              save_to=REPO_PATH)

# %%
import sys
sys.path.append(f"{REPO_PATH}/src")

# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
from torchvision import transforms, datasets
from torchvision.datasets import FashionMNIST

from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import RidgeClassifier
from sklearn.decomposition import PCA

from pytorch_impl.nns import ResNet, FCN, CNN
from pytorch_impl.nns import warm_up_batch_norm
from pytorch_impl.estimators import LinearizedSgdEstimator, SgdEstimator, MatrixExpEstimator, GradientBoostingEstimator
from pytorch_impl import ClassifierTraining
from pytorch_impl.matrix_exp import matrix_exp, compute_exp_term
from pytorch_impl.nns.utils import to_one_hot

# %%
device = torch.device('cuda:0') if (torch.cuda.is_available()) else torch.device('cpu')
num_classes = 10
device
# Out:
# device(type='cuda', index=0)

# %%
# compute M^-1 * (exp(M) - E)
def compute_exp_term(M, device, n_iter=3):
    with torch.no_grad():
        M = M.double().to(device)

        n = M.size()[0]
        norm = torch.sqrt((M ** 2).sum())
        steps = 0
        while norm > 1e-9:
            M /= 2.
            norm /= 2.
            steps += 1

        series_sum = torch.zeros([n, n]).double().to(device)
        prod = torch.eye(n).double().to(device)

        # series_sum: E + M / 2 + M^2 / 6 + ...
        for i in range(1, n_iter):
            series_sum = (series_sum + prod)
            prod = torch.matmul(prod, M) / (i + 1)

        # (exp 0) (exp 0) = (exp^2           0)
        # (sum E) (sum E) = (sum * exp + sum E)
        exp = torch.matmul(M, series_sum) + torch.eye(n).to(device)
        for step in range(steps):
            series_sum = (torch.matmul(series_sum, exp) + series_sum) / 2.
            exp = torch.matmul(exp, exp)

        return series_sum

# %%
kernels_12k = np.load('../data/kernels_12k.npz')

train_kernel = kernels_12k['train_kernel']
test_kernel  = kernels_12k['test_kernel']
labels_train = kernels_12k['labels_train']
labels_test  = kernels_12k['labels_test']

train_kernel.shape, test_kernel.shape, labels_train.shape, labels_test.shape
# Out:
# ((12800, 12800), (10000, 12800), (12800,), (10000,))

# %%
train_kernel = torch.from_numpy(train_kernel).float().to(device)
test_kernel  = torch.from_numpy(test_kernel).float().to(device)

labels_test  = torch.from_numpy(labels_test).to(device)
labels_train = torch.from_numpy(labels_train).to(device)

# %%
y_train = to_one_hot(labels_train, num_classes).to(device)

# %%
lr = 1e4

n = len(train_kernel)
reg = 0e-4 * torch.eye(n).to(device)
exp_term = - lr * compute_exp_term(- lr * (train_kernel + reg), device).float()

y_pred = torch.matmul(test_kernel, torch.matmul(exp_term, - y_train))

del exp_term

(y_pred.argmax(dim=1) == labels_test).float().mean()
# Out:
# tensor(0.8012, device='cuda:0')

# %%
del train_kernel
del test_kernel

# %%
def matmul_via_torch(numpy_matrix, torch_matrix, step=2048):
    with torch.no_grad():
        n,  m = numpy_matrix.shape
        m2, k = torch_matrix.size()
        assert m2 == m
        
        to_torch = lambda matrix: torch.from_numpy(matrix).double().to(device)
        
        result = torch.zeros([n, k]).to(device)
        for l in range(0, n, step):
            r = min(l + step, n)
            result[l:r] = torch.matmul(to_torch(numpy_matrix[l:r]), torch_matrix.double())
        return result

# %%
def boosting(train_kernel, y_train, labels_train, test_kernel, labels_test, beta=1.4, n_iter=24, lr=1e5, flips=False, block_size = 1280 * 2):
    with torch.no_grad():
        n = len(train_kernel)

        right_vector = torch.zeros([n, num_classes]).double().to(device)
        # right_vector.normal_()
        # right_vector /= np.sqrt(n)
        
        n_actual = (n // 2) if (flips) else n 
        
        n_blocks = (2 * n_actual) // (3 * block_size) + 1
        print(n_blocks)

        for iter_num in range(n_iter):
            index = torch.randperm(n_actual).to(device)
            
            if flips:
                index += n_actual * rand_bool(n_actual)
                
            y_pred_train = matmul_via_torch(train_kernel, right_vector)
            y_pred_test  = matmul_via_torch(test_kernel, right_vector)
            train_acc = (y_pred_train.argmax(dim=1) == labels_train).float().mean().item()
            test_acc  = (y_pred_test.argmax(dim=1)  == labels_test).float().mean().item()

            y_residual     = y_pred_train - y_train
            
            train_mse = (y_residual ** 2).sum(dim=1).mean().item()
            
            print(f"iteration {iter_num} train_acc {train_acc} test_acc {test_acc} train_mse {train_mse}")

            d_right_vector = torch.zeros([n, num_classes]).double().to(device)
            
            for i in range(n_blocks):
                batch_index = index[i * block_size: (i + 1) * block_size]
                batch_index_np = batch_index.cpu().numpy()
                
                K = train_kernel[batch_index_np][:, batch_index_np]
                K = torch.from_numpy(K).double().to(device)
                
                K = K + 1e-4 * torch.eye(len(K)).double().to(device)
                
                exp_term = - lr * compute_exp_term(- lr * K, device)
                d_right_vector[batch_index] = torch.matmul(exp_term, y_residual[batch_index].double()) / n_blocks
                
            pred_change = matmul_via_torch(train_kernel, d_right_vector)
            right_vector += d_right_vector * beta
            
            print(f"batches {0}-{n_blocks - 1} done")
            print(f"beta = {beta}")
            print()
            
        y_pred_train = matmul_via_torch(train_kernel, right_vector)
        y_pred_test  = matmul_via_torch(test_kernel, right_vector)
        train_acc = (y_pred_train.argmax(dim=1) == labels_train).float().mean().item()
        test_acc  = (y_pred_test.argmax(dim=1)  == labels_test).float().mean().item()

        y_residual     = y_pred_train - to_one_hot(labels_train, num_classes).double().to(device)

        train_mse = (y_residual ** 2).sum(dim=1).mean().item()

        print(f"iteration {n_iter} train_acc {train_acc:.4f} test_acc {test_acc:.4f} train_mse {train_mse}")

# %%
# %%time

kernels_50k = np.load('../data/kernels_50k.npz')

train_kernel = kernels_50k['train_kernel']
test_kernel  = kernels_50k['test_kernel']
labels_train = kernels_50k['labels_train']
labels_test  = kernels_50k['labels_test']

labels_train = torch.from_numpy(labels_train).to(device)
labels_test  = torch.from_numpy(labels_test).to(device)
y_train = to_one_hot(labels_train, num_classes).to(device)
# Out:
# CPU times: user 32.6 s, sys: 37.5 s, total: 1min 10s
# Wall time: 15min 46s

# %%
y_train = to_one_hot(labels_train, num_classes).to(device)

# %%
# %time

boosting(train_kernel, y_train, labels_train, test_kernel, labels_test, beta=1.4, lr=1e5, n_iter=100)
# Out:
# CPU times: user 0 ns, sys: 4 µs, total: 4 µs
# Wall time: 7.39 µs
# 14
# iteration 0 train_acc 0.09999999403953552 test_acc 0.09999999403953552 train_mse 10.0
# batches 0-13 done
# beta = 1.4
#
# iteration 1 train_acc 0.8350799679756165 test_acc 0.7719999551773071 train_mse 2.7111761569976807
# batches 0-13 done
# beta = 1.4
#
# iteration 2 train_acc 0.9254599809646606 test_acc 0.8180999755859375 train_mse 1.4347137212753296
# batches 0-13 done
# beta = 1.4
#
# iteration 3 train_acc 0.944599986076355 test_acc 0.8287000060081482 train_mse 1.1048145294189453
# batches 0-13 done
# beta = 1.4
#
# iteration 4 train_acc 0.9664999842643738 test_acc 0.838699996471405 train_mse 0.9468210935592651
# batches 0-13 done
# beta = 1.4
#
# iteration 5 train_acc 0.9775599837303162 test_acc 0.842799961566925 train_mse 0.8372856974601746
# batches 0-13 done
# beta = 1.4
#
# iteration 6 train_acc 0.9856599569320679 test_acc 0.8481000065803528 train_mse 0.7488650679588318
# batches 0-13 done
# beta = 1.4
#
# iteration 7 train_acc 0.9906999468803406 test_acc 0.8501999974250793 train_mse 0.6727420091629028
# batches 0-13 done
# beta = 1.4
#
# iteration 8 train_acc 0.9940799474716187 test_acc 0.8549000024795532 train_mse 0.6076700687408447
# batches 0-13 done
# beta = 1.4
#
# iteration 9 train_acc 0.995959997177124 test_acc 0.8572999835014343 train_mse 0.5507287383079529
# batches 0-13 done
# beta = 1.4
#
# iteration 10 train_acc 0.9972800016403198 test_acc 0.861299991607666 train_mse 0.5003771185874939
# batches 0-13 done
# beta = 1.4
#
# iteration 11 train_acc 0.998259961605072 test_acc 0.8633999824523926 train_mse 0.4557247459888458
# batches 0-13 done
# beta = 1.4
#
# iteration 12 train_acc 0.9987599849700928 test_acc 0.8651999831199646 train_mse 0.41594335436820984
# batches 0-13 done
# beta = 1.4
#
# iteration 13 train_acc 0.9993399977684021 test_acc 0.8669999837875366 train_mse 0.3802851438522339
# batches 0-13 done
# beta = 1.4
#
# iteration 14 train_acc 0.9995200037956238 test_acc 0.8667999505996704 train_mse 0.34802547097206116
# batches 0-13 done
# beta = 1.4
#
# iteration 15 train_acc 0.9996599555015564 test_acc 0.8684999942779541 train_mse 0.3191668689250946
# batches 0-13 done
# beta = 1.4
#
# iteration 16 train_acc 0.9998399615287781 test_acc 0.8686999678611755 train_mse 0.29283377528190613
# batches 0-13 done
# beta = 1.4
#
# iteration 17 train_acc 0.9998799562454224 test_acc 0.8705999851226807 train_mse 0.2692529559135437
# batches 0-13 done
# beta = 1.4
#
# iteration 18 train_acc 0.9998999834060669 test_acc 0.8722999691963196 train_mse 0.24775706231594086
# batches 0-13 done
# beta = 1.4
#
# iteration 19 train_acc 0.9999599456787109 test_acc 0.8720999956130981 train_mse 0.22834914922714233
# batches 0-13 done
# beta = 1.4
#
# iteration 20 train_acc 0.9999799728393555 test_acc 0.873699963092804 train_mse 0.21042126417160034
# batches 0-13 done
# beta = 1.4
#
# iteration 21 train_acc 0.9999799728393555 test_acc 0.8721999526023865 train_mse 0.19426549971103668
# batches 0-13 done
# beta = 1.4
#
# iteration 22 train_acc 1.0 test_acc 0.873699963092804 train_mse 0.17931345105171204
# batches 0-13 done
# beta = 1.4
#
# iteration 23 train_acc 0.9999799728393555 test_acc 0.8746999502182007 train_mse 0.16564026474952698
# batches 0-13 done
# beta = 1.4
#
# iteration 24 train_acc 1.0 test_acc 0.8762999773025513 train_mse 0.15311749279499054
# batches 0-13 done
# beta = 1.4
#
# iteration 25 train_acc 0.9999799728393555 test_acc 0.8745999932289124 train_mse 0.1417439877986908
# batches 0-13 done
# beta = 1.4
#
# iteration 26 train_acc 1.0 test_acc 0.8754000067710876 train_mse 0.1310916244983673
# batches 0-13 done
# beta = 1.4
#
# iteration 27 train_acc 1.0 test_acc 0.8761000037193298 train_mse 0.12144355475902557
# batches 0-13 done
# beta = 1.4
#
# iteration 28 train_acc 1.0 test_acc 0.8776999711990356 train_mse 0.11251300573348999
# batches 0-13 done
# beta = 1.4
#
# iteration 29 train_acc 1.0 test_acc 0.8768999576568604 train_mse 0.10425486415624619
# batches 0-13 done
# beta = 1.4
#
# iteration 30 train_acc 1.0 test_acc 0.875499963760376 train_mse 0.0967000350356102
# batches 0-13 done
# beta = 1.4
#
# iteration 31 train_acc 1.0 test_acc 0.8770999908447266 train_mse 0.08960665762424469
# batches 0-13 done
# beta = 1.4
#
# iteration 32 train_acc 1.0 test_acc 0.877299964427948 train_mse 0.08318815380334854
# batches 0-13 done
# beta = 1.4
#
# iteration 33 train_acc 1.0 test_acc 0.8764999508857727 train_mse 0.07720346748828888
# batches 0-13 done
# beta = 1.4
#
# iteration 34 train_acc 1.0 test_acc 0.8780999779701233 train_mse 0.07176289707422256
# batches 0-13 done
# beta = 1.4
#
# iteration 35 train_acc 1.0 test_acc 0.8774999976158142 train_mse 0.066611148416996
# batches 0-13 done
# beta = 1.4
#
# iteration 36 train_acc 1.0 test_acc 0.8770999908447266 train_mse 0.06190697103738785
# batches 0-13 done
# beta = 1.4
#
# iteration 37 train_acc 1.0 test_acc 0.8775999546051025 train_mse 0.05754739046096802
# batches 0-13 done
# beta = 1.4
#
# iteration 38 train_acc 1.0 test_acc 0.877299964427948 train_mse 0.053505297750234604
# batches 0-13 done
# beta = 1.4
#
# iteration 39 train_acc 1.0 test_acc 0.8769999742507935 train_mse 0.04976223409175873
# batches 0-13 done
# beta = 1.4
#
# iteration 40 train_acc 1.0 test_acc 0.8782999515533447 train_mse 0.04633225500583649
# batches 0-13 done
# beta = 1.4
#
# iteration 41 train_acc 1.0 test_acc 0.8783999681472778 train_mse 0.04311422258615494
# batches 0-13 done
# beta = 1.4
#
# iteration 42 train_acc 1.0 test_acc 0.8782999515533447 train_mse 0.04017413407564163
# batches 0-13 done
# beta = 1.4
#
# iteration 43 train_acc 1.0 test_acc 0.8779999613761902 train_mse 0.03743128851056099
# batches 0-13 done
# beta = 1.4
#
# iteration 44 train_acc 1.0 test_acc 0.8783999681472778 train_mse 0.03486671671271324
# batches 0-13 done
# beta = 1.4
#
# iteration 45 train_acc 1.0 test_acc 0.8782999515533447 train_mse 0.032496482133865356
# batches 0-13 done
# beta = 1.4
#
# iteration 46 train_acc 1.0 test_acc 0.877299964427948 train_mse 0.030316704884171486
# batches 0-13 done
# beta = 1.4
#
# iteration 47 train_acc 1.0 test_acc 0.8782999515533447 train_mse 0.02825767546892166
# batches 0-13 done
# beta = 1.4
#
# iteration 48 train_acc 1.0 test_acc 0.878600001335144 train_mse 0.026386020705103874
# batches 0-13 done
# beta = 1.4
#
# iteration 49 train_acc 1.0 test_acc 0.8794999718666077 train_mse 0.02459011599421501
# batches 0-13 done
# beta = 1.4
#
# iteration 50 train_acc 1.0 test_acc 0.8773999810218811 train_mse 0.02297165058553219
# batches 0-13 done
# beta = 1.4
#
# iteration 51 train_acc 1.0 test_acc 0.8782999515533447 train_mse 0.021435847505927086
# batches 0-13 done
# beta = 1.4
#
# iteration 52 train_acc 1.0 test_acc 0.8783999681472778 train_mse 0.020003898069262505
# batches 0-13 done
# beta = 1.4
#
# iteration 53 train_acc 1.0 test_acc 0.8782999515533447 train_mse 0.018686875700950623
# batches 0-13 done
# beta = 1.4
#
# iteration 54 train_acc 1.0 test_acc 0.8780999779701233 train_mse 0.017439061775803566
# batches 0-13 done
# beta = 1.4
#
# iteration 55 train_acc 1.0 test_acc 0.8784999847412109 train_mse 0.016288399696350098
# batches 0-13 done
# beta = 1.4
#
# iteration 56 train_acc 1.0 test_acc 0.8784999847412109 train_mse 0.01522549893707037
# batches 0-13 done
# beta = 1.4
#
# iteration 57 train_acc 1.0 test_acc 0.8780999779701233 train_mse 0.014223383739590645
# batches 0-13 done
# beta = 1.4
#
# iteration 58 train_acc 1.0 test_acc 0.8779999613761902 train_mse 0.013293461874127388
# batches 0-13 done
# beta = 1.4
#
# iteration 59 train_acc 1.0 test_acc 0.8777999877929688 train_mse 0.0124205332249403
# batches 0-13 done
# beta = 1.4
#
# iteration 60 train_acc 1.0 test_acc 0.878600001335144 train_mse 0.011612026020884514
# batches 0-13 done
# beta = 1.4
#
# iteration 61 train_acc 1.0 test_acc 0.878600001335144 train_mse 0.010867457836866379
# batches 0-13 done
# beta = 1.4
#
# iteration 62 train_acc 1.0 test_acc 0.878600001335144 train_mse 0.010162015445530415
# batches 0-13 done
# beta = 1.4
#
# iteration 63 train_acc 1.0 test_acc 0.8783999681472778 train_mse 0.00950430054217577
# batches 0-13 done
# beta = 1.4
#
# iteration 64 train_acc 1.0 test_acc 0.8788999915122986 train_mse 0.008893296122550964
# batches 0-13 done
# beta = 1.4
#
# iteration 65 train_acc 1.0 test_acc 0.8783999681472778 train_mse 0.008314952254295349
# batches 0-13 done
# beta = 1.4
#
# iteration 66 train_acc 1.0 test_acc 0.8789999485015869 train_mse 0.0077830166555941105
# batches 0-13 done
# beta = 1.4
#
# iteration 67 train_acc 1.0 test_acc 0.8791999816894531 train_mse 0.0072861663065850735
# batches 0-13 done
# beta = 1.4
#
# iteration 68 train_acc 1.0 test_acc 0.878600001335144 train_mse 0.006818495690822601
# batches 0-13 done
# beta = 1.4
#
# iteration 69 train_acc 1.0 test_acc 0.8788999915122986 train_mse 0.006389101501554251
# batches 0-13 done
# beta = 1.4
#
# iteration 70 train_acc 1.0 test_acc 0.8793999552726746 train_mse 0.005984936375170946
# batches 0-13 done
# beta = 1.4
#
# iteration 71 train_acc 1.0 test_acc 0.8787999749183655 train_mse 0.005598859861493111
# batches 0-13 done
# beta = 1.4
#
# iteration 72 train_acc 1.0 test_acc 0.8791999816894531 train_mse 0.005250848364084959
# batches 0-13 done
# beta = 1.4
#
# iteration 73 train_acc 1.0 test_acc 0.8786999583244324 train_mse 0.004920489154756069
# batches 0-13 done
# beta = 1.4
#
# iteration 74 train_acc 1.0 test_acc 0.8789999485015869 train_mse 0.004612274467945099
# batches 0-13 done
# beta = 1.4
#
# iteration 75 train_acc 1.0 test_acc 0.8795999884605408 train_mse 0.0043228259310126305
# batches 0-13 done
# beta = 1.4
#
# iteration 76 train_acc 1.0 test_acc 0.8791999816894531 train_mse 0.00405342411249876
# batches 0-13 done
# beta = 1.4
#
# iteration 77 train_acc 1.0 test_acc 0.8794999718666077 train_mse 0.0037994517479091883
# batches 0-13 done
# beta = 1.4
#
# iteration 78 train_acc 1.0 test_acc 0.8791999816894531 train_mse 0.003560652956366539
# batches 0-13 done
# beta = 1.4
#
# iteration 79 train_acc 1.0 test_acc 0.87909996509552 train_mse 0.0033367907162755728
# batches 0-13 done
# beta = 1.4
#
# iteration 80 train_acc 1.0 test_acc 0.8795999884605408 train_mse 0.0031288238242268562
# batches 0-13 done
# beta = 1.4
#
# iteration 81 train_acc 1.0 test_acc 0.8794999718666077 train_mse 0.002934153890237212
# batches 0-13 done
# beta = 1.4
#
# iteration 82 train_acc 1.0 test_acc 0.8792999982833862 train_mse 0.00275241257622838
# batches 0-13 done
# beta = 1.4
#
# iteration 83 train_acc 1.0 test_acc 0.8795999884605408 train_mse 0.002582603134214878
# batches 0-13 done
# beta = 1.4
#
# iteration 84 train_acc 1.0 test_acc 0.8792999982833862 train_mse 0.0024225881788879633
# batches 0-13 done
# beta = 1.4
#
# iteration 85 train_acc 1.0 test_acc 0.8797000050544739 train_mse 0.002273866906762123
# batches 0-13 done
# beta = 1.4
#
# iteration 86 train_acc 1.0 test_acc 0.8792999982833862 train_mse 0.0021346090361475945
# batches 0-13 done
# beta = 1.4
#
# iteration 87 train_acc 1.0 test_acc 0.8792999982833862 train_mse 0.002004043897613883
# batches 0-13 done
# beta = 1.4
#
# iteration 88 train_acc 1.0 test_acc 0.8797000050544739 train_mse 0.0018815496005117893
# batches 0-13 done
# beta = 1.4
#
# iteration 89 train_acc 1.0 test_acc 0.8795999884605408 train_mse 0.0017679384909570217
# batches 0-13 done
# beta = 1.4
#
# iteration 90 train_acc 1.0 test_acc 0.8795999884605408 train_mse 0.0016597539652138948
# batches 0-13 done
# beta = 1.4
#
# iteration 91 train_acc 1.0 test_acc 0.8793999552726746 train_mse 0.0015595054719597101
# batches 0-13 done
# beta = 1.4
#
# iteration 92 train_acc 1.0 test_acc 0.8797000050544739 train_mse 0.0014638259308412671
# batches 0-13 done
# beta = 1.4
#
# iteration 93 train_acc 1.0 test_acc 0.8794999718666077 train_mse 0.0013757918495684862
# batches 0-13 done
# beta = 1.4
#
# iteration 94 train_acc 1.0 test_acc 0.8797999620437622 train_mse 0.001293600769713521
# batches 0-13 done
# beta = 1.4
#
# iteration 95 train_acc 1.0 test_acc 0.8795999884605408 train_mse 0.001215557218529284
# batches 0-13 done
# beta = 1.4
#
# iteration 96 train_acc 1.0 test_acc 0.8797000050544739 train_mse 0.0011420254595577717
# batches 0-13 done
# beta = 1.4
#
# iteration 97 train_acc 1.0 test_acc 0.8797999620437622 train_mse 0.001072593149729073
# batches 0-13 done
# beta = 1.4
#
# iteration 98 train_acc 1.0 test_acc 0.8797000050544739 train_mse 0.0010099555365741253
# batches 0-13 done
# beta = 1.4
#
# iteration 99 train_acc 1.0 test_acc 0.8798999786376953 train_mse 0.00094933359650895
# batches 0-13 done
# beta = 1.4
#
# iteration 100 train_acc 1.0000 test_acc 0.8799 train_mse 0.0008923202502266671

# %%
# %%time

kernels_myrtle10 = np.load('../data/myrtle10_kernels.npz')

train_kernel = kernels_myrtle10['train_kernel']
test_kernel  = kernels_myrtle10['test_kernel']
labels_train = kernels_myrtle10['labels_train']
labels_test  = kernels_myrtle10['labels_test']

labels_train = torch.from_numpy(labels_train).to(device)
labels_test  = torch.from_numpy(labels_test).to(device)
y_train = to_one_hot(labels_train, num_classes).to(device)
# Out:
# CPU times: user 28.4 s, sys: 42.4 s, total: 1min 10s
# Wall time: 14min 17s

# %%
train_kernel[:4,:4]
# Out:
# array([[0.99999999, 0.99621984, 0.99376137, 0.99705303],
#        [0.99621984, 0.99999993, 0.99273713, 0.99698744],
#        [0.99376137, 0.99273713, 0.99999995, 0.9928886 ],
#        [0.99705303, 0.99698744, 0.9928886 , 0.99999996]])

# %%
# %%time

boosting(train_kernel, y_train, labels_train, test_kernel, labels_test, beta=1, lr=1e5, n_iter=128, block_size=2 * 1280)
# Out:
# 14
# iteration 0 train_acc 0.09999999403953552 test_acc 0.09650000184774399 train_mse 10.0
# batches 0-13 done
# beta = 1
#
# iteration 1 train_acc 0.8500399589538574 test_acc 0.7765000462532043 train_mse 1.6379437446594238
# batches 0-13 done
# beta = 1
#
# iteration 2 train_acc 0.9042399525642395 test_acc 0.8055000305175781 train_mse 1.3548200130462646
# batches 0-13 done
# beta = 1
#
# iteration 3 train_acc 0.9343799948692322 test_acc 0.8195000290870667 train_mse 1.1855255365371704
# batches 0-13 done
# beta = 1
#
# iteration 4 train_acc 0.9528999924659729 test_acc 0.8255000114440918 train_mse 1.061790108680725
# batches 0-13 done
# beta = 1
#
# iteration 5 train_acc 0.9666599631309509 test_acc 0.8335000276565552 train_mse 0.9627645015716553
# batches 0-13 done
# beta = 1
#
# iteration 6 train_acc 0.9761599898338318 test_acc 0.8350000381469727 train_mse 0.880385160446167
# batches 0-13 done
# beta = 1
#
# iteration 7 train_acc 0.9825399518013 test_acc 0.8390000462532043 train_mse 0.8100934028625488
# batches 0-13 done
# beta = 1
#
# iteration 8 train_acc 0.9877199530601501 test_acc 0.843500018119812 train_mse 0.7489526271820068
# batches 0-13 done
# beta = 1
#
# iteration 9 train_acc 0.9910799860954285 test_acc 0.8420000672340393 train_mse 0.6952911019325256
# batches 0-13 done
# beta = 1
#
# iteration 10 train_acc 0.9936599731445312 test_acc 0.843500018119812 train_mse 0.647045910358429
# batches 0-13 done
# beta = 1
#
# iteration 11 train_acc 0.9955799579620361 test_acc 0.8445000648498535 train_mse 0.6038148403167725
# batches 0-13 done
# beta = 1
#
# iteration 12 train_acc 0.9966599941253662 test_acc 0.8485000133514404 train_mse 0.5651131272315979
# batches 0-13 done
# beta = 1
#
# iteration 13 train_acc 0.9975399971008301 test_acc 0.8510000109672546 train_mse 0.5293790698051453
# batches 0-13 done
# beta = 1
#
# iteration 14 train_acc 0.9985399842262268 test_acc 0.8535000681877136 train_mse 0.49712929129600525
# batches 0-13 done
# beta = 1
#
# iteration 15 train_acc 0.9987799525260925 test_acc 0.8525000214576721 train_mse 0.46763163805007935
# batches 0-13 done
# beta = 1
#
# iteration 16 train_acc 0.9990599751472473 test_acc 0.8545000553131104 train_mse 0.4404684007167816
# batches 0-13 done
# beta = 1
#
# iteration 17 train_acc 0.9994399547576904 test_acc 0.8525000214576721 train_mse 0.4154416620731354
# batches 0-13 done
# beta = 1
#
# iteration 18 train_acc 0.9996399879455566 test_acc 0.8535000681877136 train_mse 0.39227622747421265
# batches 0-13 done
# beta = 1
#
# iteration 19 train_acc 0.9996999502182007 test_acc 0.8565000295639038 train_mse 0.37084686756134033
# batches 0-13 done
# beta = 1
#
# iteration 20 train_acc 0.999779999256134 test_acc 0.8570000529289246 train_mse 0.35097646713256836
# batches 0-13 done
# beta = 1
#
# iteration 21 train_acc 0.9998399615287781 test_acc 0.8560000658035278 train_mse 0.3323841392993927
# batches 0-13 done
# beta = 1
#
# iteration 22 train_acc 0.9998799562454224 test_acc 0.8570000529289246 train_mse 0.31515687704086304
# batches 0-13 done
# beta = 1
#
# iteration 23 train_acc 0.9998599886894226 test_acc 0.8610000610351562 train_mse 0.29904672503471375
# batches 0-13 done
# beta = 1
#
# iteration 24 train_acc 0.9998799562454224 test_acc 0.8575000166893005 train_mse 0.2838628888130188
# batches 0-13 done
# beta = 1
#
# iteration 25 train_acc 0.9999599456787109 test_acc 0.8565000295639038 train_mse 0.2696879506111145
# batches 0-13 done
# beta = 1
#
# iteration 26 train_acc 0.9999599456787109 test_acc 0.8580000400543213 train_mse 0.2564021050930023
# batches 0-13 done
# beta = 1
#
# iteration 27 train_acc 1.0 test_acc 0.8600000143051147 train_mse 0.2439149171113968
# batches 0-13 done
# beta = 1
#
# iteration 28 train_acc 1.0 test_acc 0.8595000505447388 train_mse 0.23205123841762543
# batches 0-13 done
# beta = 1
#
# iteration 29 train_acc 1.0 test_acc 0.8600000143051147 train_mse 0.22099719941616058
# batches 0-13 done
# beta = 1
#
# iteration 30 train_acc 1.0 test_acc 0.8600000143051147 train_mse 0.21055054664611816
# batches 0-13 done
# beta = 1
#
# iteration 31 train_acc 1.0 test_acc 0.8580000400543213 train_mse 0.20073120296001434
# batches 0-13 done
# beta = 1
#
# iteration 32 train_acc 1.0 test_acc 0.8565000295639038 train_mse 0.1914554238319397
# batches 0-13 done
# beta = 1
#
# iteration 33 train_acc 1.0 test_acc 0.8570000529289246 train_mse 0.1826358586549759
# batches 0-13 done
# beta = 1
#
# iteration 34 train_acc 1.0 test_acc 0.858500063419342 train_mse 0.1744072288274765
# batches 0-13 done
# beta = 1
#
# iteration 35 train_acc 1.0 test_acc 0.859000027179718 train_mse 0.1665804386138916
# batches 0-13 done
# beta = 1
#
# iteration 36 train_acc 1.0 test_acc 0.859000027179718 train_mse 0.15926645696163177
# batches 0-13 done
# beta = 1
#
# iteration 37 train_acc 1.0 test_acc 0.8580000400543213 train_mse 0.15223965048789978
# batches 0-13 done
# beta = 1
#
# iteration 38 train_acc 1.0 test_acc 0.8555000424385071 train_mse 0.14562198519706726
# batches 0-13 done
# beta = 1
#
# iteration 39 train_acc 1.0 test_acc 0.8580000400543213 train_mse 0.13934771716594696
# batches 0-13 done
# beta = 1
#
# iteration 40 train_acc 1.0 test_acc 0.858500063419342 train_mse 0.1333785206079483
# batches 0-13 done
# beta = 1
#
# iteration 41 train_acc 1.0 test_acc 0.8570000529289246 train_mse 0.1276317834854126
# batches 0-13 done
# beta = 1
#
# iteration 42 train_acc 1.0 test_acc 0.8580000400543213 train_mse 0.12226133793592453
# batches 0-13 done
# beta = 1
#
# iteration 43 train_acc 1.0 test_acc 0.8580000400543213 train_mse 0.11713217198848724
# batches 0-13 done
# beta = 1
#
# iteration 44 train_acc 1.0 test_acc 0.8575000166893005 train_mse 0.11221776902675629
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed eval> in <module>
#
# <ipython-input-30-55bab2383e31> in boosting(train_kernel, y_train, labels_train, test_kernel, labels_test, beta, n_iter, lr, flips, block_size)
#      33             for i in range(n_blocks):
#      34                 batch_index = index[i * block_size: (i + 1) * block_size]
# ---> 35                 batch_index_np = batch_index.cpu().numpy()
#      36
#      37                 K = train_kernel[batch_index_np][:, batch_index_np]
#
# KeyboardInterrupt:

# %%
# %%time

kernels_myrtle7 = np.load('../data/myrtle7_kernels.npz')

train_kernel = kernels_myrtle7['train_kernel']
test_kernel  = kernels_myrtle7['test_kernel']
labels_train = kernels_myrtle7['labels_train']
labels_test  = kernels_myrtle7['labels_test']

labels_train = torch.from_numpy(labels_train).to(device)
labels_test  = torch.from_numpy(labels_test).to(device)
y_train = to_one_hot(labels_train, num_classes).to(device)
# Out:
# CPU times: user 31.1 s, sys: 21 s, total: 52 s
# Wall time: 15min 20s

# %%
train_kernel[:4,:4]
# Out:
# array([[0.99999996, 0.99566936, 0.99371328, 0.99647623],
#        [0.99566936, 1.        , 0.99317682, 0.99668258],
#        [0.99371328, 0.99317682, 0.99999998, 0.99330106],
#        [0.99647623, 0.99668258, 0.99330106, 0.99999994]])

# %%
# %%time

boosting(train_kernel, y_train, labels_train, test_kernel, labels_test, beta=1, lr=1e5, n_iter=128, block_size=2 * 1280)
# Out:
# 14
# iteration 0 train_acc 0.09999999403953552 test_acc 0.09650000184774399 train_mse 10.0
# batches 0-13 done
# beta = 1
#
# iteration 1 train_acc 0.8427799940109253 test_acc 0.7780000567436218 train_mse 1.6839958429336548
# batches 0-13 done
# beta = 1
#
# iteration 2 train_acc 0.8982399702072144 test_acc 0.796500027179718 train_mse 1.4002586603164673
# batches 0-13 done
# beta = 1
#
# iteration 3 train_acc 0.9285399913787842 test_acc 0.8105000257492065 train_mse 1.2289040088653564
# batches 0-13 done
# beta = 1
#
# iteration 4 train_acc 0.9489599466323853 test_acc 0.8230000138282776 train_mse 1.1028614044189453
# batches 0-13 done
# beta = 1
#
# iteration 5 train_acc 0.9634999632835388 test_acc 0.8255000114440918 train_mse 1.0025246143341064
# batches 0-13 done
# beta = 1
#
# iteration 6 train_acc 0.9734799861907959 test_acc 0.8225000500679016 train_mse 0.9193209409713745
# batches 0-13 done
# beta = 1
#
# iteration 7 train_acc 0.9807599782943726 test_acc 0.8315000534057617 train_mse 0.8478538990020752
# batches 0-13 done
# beta = 1
#
# iteration 8 train_acc 0.9863999485969543 test_acc 0.8335000276565552 train_mse 0.7853608131408691
# batches 0-13 done
# beta = 1
#
# iteration 9 train_acc 0.9898399710655212 test_acc 0.8385000228881836 train_mse 0.7306733131408691
# batches 0-13 done
# beta = 1
#
# iteration 10 train_acc 0.9928999543190002 test_acc 0.8440000414848328 train_mse 0.6816552877426147
# batches 0-13 done
# beta = 1
#
# iteration 11 train_acc 0.9946799874305725 test_acc 0.8410000205039978 train_mse 0.6376289129257202
# batches 0-13 done
# beta = 1
#
# iteration 12 train_acc 0.9961400032043457 test_acc 0.8440000414848328 train_mse 0.5978880524635315
# batches 0-13 done
# beta = 1
#
# iteration 13 train_acc 0.9971999526023865 test_acc 0.8415000438690186 train_mse 0.5616434216499329
# batches 0-13 done
# beta = 1
#
# iteration 14 train_acc 0.9978399872779846 test_acc 0.843000054359436 train_mse 0.5285155177116394
# batches 0-13 done
# beta = 1
#
# iteration 15 train_acc 0.9987599849700928 test_acc 0.8415000438690186 train_mse 0.4981376528739929
# batches 0-13 done
# beta = 1
#
# iteration 16 train_acc 0.9990599751472473 test_acc 0.843000054359436 train_mse 0.4700526297092438
# batches 0-13 done
# beta = 1
#
# iteration 17 train_acc 0.9993599653244019 test_acc 0.8455000519752502 train_mse 0.44422319531440735
# batches 0-13 done
# beta = 1
#
# iteration 18 train_acc 0.9995399713516235 test_acc 0.8455000519752502 train_mse 0.42032116651535034
# batches 0-13 done
# beta = 1
#
# iteration 19 train_acc 0.9997599720954895 test_acc 0.846500039100647 train_mse 0.39831095933914185
# batches 0-13 done
# beta = 1
#
# iteration 20 train_acc 0.9998399615287781 test_acc 0.843000054359436 train_mse 0.37761181592941284
# batches 0-13 done
# beta = 1
#
# iteration 21 train_acc 0.9998799562454224 test_acc 0.8460000157356262 train_mse 0.3583798408508301
# batches 0-13 done
# beta = 1
#
# iteration 22 train_acc 0.9998799562454224 test_acc 0.8485000133514404 train_mse 0.3404867947101593
# batches 0-13 done
# beta = 1
#
# iteration 23 train_acc 0.9999599456787109 test_acc 0.8490000367164612 train_mse 0.3236284852027893
# batches 0-13 done
# beta = 1
#
# iteration 24 train_acc 0.9999399781227112 test_acc 0.8475000262260437 train_mse 0.30778980255126953
# batches 0-13 done
# beta = 1
#
# iteration 25 train_acc 0.9999799728393555 test_acc 0.8480000495910645 train_mse 0.2930700182914734
# batches 0-13 done
# beta = 1
#
# iteration 26 train_acc 0.9999599456787109 test_acc 0.8495000600814819 train_mse 0.27920159697532654
# batches 0-13 done
# beta = 1
#
# iteration 27 train_acc 1.0 test_acc 0.8505000472068787 train_mse 0.26605814695358276
# batches 0-13 done
# beta = 1
#
# iteration 28 train_acc 0.9999799728393555 test_acc 0.8495000600814819 train_mse 0.2537762522697449
# batches 0-13 done
# beta = 1
#
# iteration 29 train_acc 1.0 test_acc 0.8490000367164612 train_mse 0.24215522408485413
# batches 0-13 done
# beta = 1
#
# iteration 30 train_acc 1.0 test_acc 0.8480000495910645 train_mse 0.23124369978904724
# batches 0-13 done
# beta = 1
#
# iteration 31 train_acc 1.0 test_acc 0.8495000600814819 train_mse 0.22095738351345062
# batches 0-13 done
# beta = 1
#
# iteration 32 train_acc 1.0 test_acc 0.8500000238418579 train_mse 0.21105478703975677
# batches 0-13 done
# beta = 1
#
# iteration 33 train_acc 1.0 test_acc 0.8480000495910645 train_mse 0.20183025300502777
# batches 0-13 done
# beta = 1
#
# iteration 34 train_acc 1.0 test_acc 0.8500000238418579 train_mse 0.19316734373569489
# batches 0-13 done
# beta = 1
#
# iteration 35 train_acc 1.0 test_acc 0.8480000495910645 train_mse 0.18483497202396393
# batches 0-13 done
# beta = 1
#
# iteration 36 train_acc 1.0 test_acc 0.8490000367164612 train_mse 0.1769213080406189
# batches 0-13 done
# beta = 1
#
# iteration 37 train_acc 1.0 test_acc 0.8490000367164612 train_mse 0.16949856281280518
# batches 0-13 done
# beta = 1
#
# iteration 38 train_acc 1.0 test_acc 0.8480000495910645 train_mse 0.16240349411964417
# batches 0-13 done
# beta = 1
#
# iteration 39 train_acc 1.0 test_acc 0.8490000367164612 train_mse 0.1556304395198822
# batches 0-13 done
# beta = 1
#
# iteration 40 train_acc 1.0 test_acc 0.846500039100647 train_mse 0.14921879768371582
# batches 0-13 done
# beta = 1
#
# iteration 41 train_acc 1.0 test_acc 0.8485000133514404 train_mse 0.1431427001953125
# batches 0-13 done
# beta = 1
#
# iteration 42 train_acc 1.0 test_acc 0.8485000133514404 train_mse 0.1373395472764969
# batches 0-13 done
# beta = 1
#
# iteration 43 train_acc 1.0 test_acc 0.8455000519752502 train_mse 0.1318303346633911
# batches 0-13 done
# beta = 1
#
# iteration 44 train_acc 1.0 test_acc 0.8490000367164612 train_mse 0.1265728622674942
# batches 0-13 done
# beta = 1
#
# iteration 45 train_acc 1.0 test_acc 0.8470000624656677 train_mse 0.1215653121471405
# batches 0-13 done
# beta = 1
#
# iteration 46 train_acc 1.0 test_acc 0.8475000262260437 train_mse 0.11673922836780548
# batches 0-13 done
# beta = 1
#
# iteration 47 train_acc 1.0 test_acc 0.8470000624656677 train_mse 0.11217061430215836
# batches 0-13 done
# beta = 1
#
# iteration 48 train_acc 1.0 test_acc 0.8485000133514404 train_mse 0.10783583670854568
# batches 0-13 done
# beta = 1
#
# iteration 49 train_acc 1.0 test_acc 0.8480000495910645 train_mse 0.10364185273647308
# batches 0-13 done
# beta = 1
#
# iteration 50 train_acc 1.0 test_acc 0.8500000238418579 train_mse 0.09966491907835007
# batches 0-13 done
# beta = 1
#
# iteration 51 train_acc 1.0 test_acc 0.8485000133514404 train_mse 0.09588278830051422
# batches 0-13 done
# beta = 1
#
# iteration 52 train_acc 1.0 test_acc 0.8485000133514404 train_mse 0.09221406280994415
# batches 0-13 done
# beta = 1
#
# iteration 53 train_acc 1.0 test_acc 0.8485000133514404 train_mse 0.08876308053731918
# batches 0-13 done
# beta = 1
#
# iteration 54 train_acc 1.0 test_acc 0.8485000133514404 train_mse 0.08544351160526276
# batches 0-13 done
# beta = 1
#
# iteration 55 train_acc 1.0 test_acc 0.8495000600814819 train_mse 0.08225052803754807
# batches 0-13 done
# beta = 1
#
# iteration 56 train_acc 1.0 test_acc 0.8495000600814819 train_mse 0.07923059910535812
# batches 0-13 done
# beta = 1
#
# iteration 57 train_acc 1.0 test_acc 0.8475000262260437 train_mse 0.07626554369926453
# batches 0-13 done
# beta = 1
#
# iteration 58 train_acc 1.0 test_acc 0.8480000495910645 train_mse 0.07347428053617477
# batches 0-13 done
# beta = 1
#
# iteration 59 train_acc 1.0 test_acc 0.8480000495910645 train_mse 0.07080236077308655
# batches 0-13 done
# beta = 1
#
# iteration 60 train_acc 1.0 test_acc 0.8500000238418579 train_mse 0.06824033707380295
# batches 0-13 done
# beta = 1
#
# iteration 61 train_acc 1.0 test_acc 0.8490000367164612 train_mse 0.06577854603528976
# batches 0-13 done
# beta = 1
#
# iteration 62 train_acc 1.0 test_acc 0.8500000238418579 train_mse 0.06341496109962463
# batches 0-13 done
# beta = 1
#
# iteration 63 train_acc 1.0 test_acc 0.8495000600814819 train_mse 0.061140742152929306
# batches 0-13 done
# beta = 1
#
# iteration 64 train_acc 1.0 test_acc 0.8485000133514404 train_mse 0.05897149443626404
# batches 0-13 done
# beta = 1
#
# iteration 65 train_acc 1.0 test_acc 0.8480000495910645 train_mse 0.05688866227865219
# batches 0-13 done
# beta = 1
#
# iteration 66 train_acc 1.0 test_acc 0.8495000600814819 train_mse 0.05487632751464844
# batches 0-13 done
# beta = 1
#
# iteration 67 train_acc 1.0 test_acc 0.8485000133514404 train_mse 0.05295892432332039
# batches 0-13 done
# beta = 1
#
# iteration 68 train_acc 1.0 test_acc 0.8485000133514404 train_mse 0.05110549554228783
# batches 0-13 done
# beta = 1
#
# iteration 69 train_acc 1.0 test_acc 0.8490000367164612 train_mse 0.0493013896048069
# batches 0-13 done
# beta = 1
#
# iteration 70 train_acc 1.0 test_acc 0.8495000600814819 train_mse 0.04760582745075226
# batches 0-13 done
# beta = 1
#
# iteration 71 train_acc 1.0 test_acc 0.8475000262260437 train_mse 0.04595492407679558
# batches 0-13 done
# beta = 1
#
# iteration 72 train_acc 1.0 test_acc 0.8475000262260437 train_mse 0.0443650484085083
# batches 0-13 done
# beta = 1
#
# iteration 73 train_acc 1.0 test_acc 0.8480000495910645 train_mse 0.042867470532655716
# batches 0-13 done
# beta = 1
#
# iteration 74 train_acc 1.0 test_acc 0.8495000600814819 train_mse 0.04139506071805954
# batches 0-13 done
# beta = 1
#
# iteration 75 train_acc 1.0 test_acc 0.8485000133514404 train_mse 0.03998487815260887
# batches 0-13 done
# beta = 1
#
# iteration 76 train_acc 1.0 test_acc 0.8480000495910645 train_mse 0.03862246125936508
# batches 0-13 done
# beta = 1
#
# iteration 77 train_acc 1.0 test_acc 0.8470000624656677 train_mse 0.03730950504541397
# batches 0-13 done
# beta = 1
#
# iteration 78 train_acc 1.0 test_acc 0.8470000624656677 train_mse 0.03604681417346001
# batches 0-13 done
# beta = 1
#
# iteration 79 train_acc 1.0 test_acc 0.8475000262260437 train_mse 0.03484058007597923
# batches 0-13 done
# beta = 1
#
# iteration 80 train_acc 1.0 test_acc 0.8460000157356262 train_mse 0.03367486223578453
# batches 0-13 done
# beta = 1
#
# iteration 81 train_acc 1.0 test_acc 0.8485000133514404 train_mse 0.03255278244614601
# batches 0-13 done
# beta = 1
#
# iteration 82 train_acc 1.0 test_acc 0.8470000624656677 train_mse 0.031469035893678665
# batches 0-13 done
# beta = 1
#
# iteration 83 train_acc 1.0 test_acc 0.8490000367164612 train_mse 0.030417216941714287
# batches 0-13 done
# beta = 1
#
# iteration 84 train_acc 1.0 test_acc 0.8480000495910645 train_mse 0.02941076271235943
# batches 0-13 done
# beta = 1
#
# iteration 85 train_acc 1.0 test_acc 0.8470000624656677 train_mse 0.028445836156606674
# batches 0-13 done
# beta = 1
#
# iteration 86 train_acc 1.0 test_acc 0.8480000495910645 train_mse 0.02750828117132187
# batches 0-13 done
# beta = 1
#
# iteration 87 train_acc 1.0 test_acc 0.8475000262260437 train_mse 0.02660795859992504
# batches 0-13 done
# beta = 1
#
# iteration 88 train_acc 1.0 test_acc 0.8495000600814819 train_mse 0.025742216035723686
# batches 0-13 done
# beta = 1
#
# iteration 89 train_acc 1.0 test_acc 0.8475000262260437 train_mse 0.02491186000406742
# batches 0-13 done
# beta = 1
#
# iteration 90 train_acc 1.0 test_acc 0.8475000262260437 train_mse 0.02410869486629963
# batches 0-13 done
# beta = 1
#
# iteration 91 train_acc 1.0 test_acc 0.8475000262260437 train_mse 0.02332293428480625
# batches 0-13 done
# beta = 1
#
# iteration 92 train_acc 1.0 test_acc 0.8475000262260437 train_mse 0.022566620260477066
# batches 0-13 done
# beta = 1
#
# iteration 93 train_acc 1.0 test_acc 0.846500039100647 train_mse 0.021842924878001213
# batches 0-13 done
# beta = 1
#
# iteration 94 train_acc 1.0 test_acc 0.8480000495910645 train_mse 0.021144257858395576
# batches 0-13 done
# beta = 1
#
# iteration 95 train_acc 1.0 test_acc 0.8480000495910645 train_mse 0.02046380192041397
# batches 0-13 done
# beta = 1
#
# iteration 96 train_acc 1.0 test_acc 0.8470000624656677 train_mse 0.01980993151664734
# batches 0-13 done
# beta = 1
#
# iteration 97 train_acc 1.0 test_acc 0.8470000624656677 train_mse 0.01917446404695511
# batches 0-13 done
# beta = 1
#
# iteration 98 train_acc 1.0 test_acc 0.8470000624656677 train_mse 0.01856890879571438
# batches 0-13 done
# beta = 1
#
# iteration 99 train_acc 1.0 test_acc 0.8470000624656677 train_mse 0.01798289455473423
# batches 0-13 done
# beta = 1
#
# iteration 100 train_acc 1.0 test_acc 0.8475000262260437 train_mse 0.01741643436253071
# batches 0-13 done
# beta = 1
#
# iteration 101 train_acc 1.0 test_acc 0.8475000262260437 train_mse 0.016869498416781425
# batches 0-13 done
# beta = 1
#
# iteration 102 train_acc 1.0 test_acc 0.8470000624656677 train_mse 0.016345031559467316
# batches 0-13 done
# beta = 1
#
# iteration 103 train_acc 1.0 test_acc 0.8475000262260437 train_mse 0.01582559570670128
# batches 0-13 done
# beta = 1
#
# iteration 104 train_acc 1.0 test_acc 0.8470000624656677 train_mse 0.015331967733800411
# batches 0-13 done
# beta = 1
#
# iteration 105 train_acc 1.0 test_acc 0.8470000624656677 train_mse 0.014856109395623207
# batches 0-13 done
# beta = 1
#
# iteration 106 train_acc 1.0 test_acc 0.8480000495910645 train_mse 0.014394605532288551
# batches 0-13 done
# beta = 1
#
# iteration 107 train_acc 1.0 test_acc 0.8470000624656677 train_mse 0.01394800003618002
# batches 0-13 done
# beta = 1
#
# iteration 108 train_acc 1.0 test_acc 0.8470000624656677 train_mse 0.013517594896256924
# batches 0-13 done
# beta = 1
#
# iteration 109 train_acc 1.0 test_acc 0.8470000624656677 train_mse 0.013103905133903027
# batches 0-13 done
# beta = 1
#
# iteration 110 train_acc 1.0 test_acc 0.8475000262260437 train_mse 0.012699184007942677
# batches 0-13 done
# beta = 1
#
# iteration 111 train_acc 1.0 test_acc 0.8475000262260437 train_mse 0.01231418177485466
# batches 0-13 done
# beta = 1
#
# iteration 112 train_acc 1.0 test_acc 0.8475000262260437 train_mse 0.011932858265936375
# batches 0-13 done
# beta = 1
#
# iteration 113 train_acc 1.0 test_acc 0.846500039100647 train_mse 0.011568198911845684
# batches 0-13 done
# beta = 1
#
# iteration 114 train_acc 1.0 test_acc 0.8480000495910645 train_mse 0.01121186651289463
# batches 0-13 done
# beta = 1
#
# iteration 115 train_acc 1.0 test_acc 0.8470000624656677 train_mse 0.010870683006942272
# batches 0-13 done
# beta = 1
#
# iteration 116 train_acc 1.0 test_acc 0.8475000262260437 train_mse 0.010542480275034904
# batches 0-13 done
# beta = 1
#
# iteration 117 train_acc 1.0 test_acc 0.846500039100647 train_mse 0.010220123454928398
# batches 0-13 done
# beta = 1
#
# iteration 118 train_acc 1.0 test_acc 0.8480000495910645 train_mse 0.009909547865390778
# batches 0-13 done
# beta = 1
#
# iteration 119 train_acc 1.0 test_acc 0.8475000262260437 train_mse 0.009610648266971111
# batches 0-13 done
# beta = 1
#
# iteration 120 train_acc 1.0 test_acc 0.8475000262260437 train_mse 0.009318963624536991
# batches 0-13 done
# beta = 1
#
# iteration 121 train_acc 1.0 test_acc 0.8475000262260437 train_mse 0.009039154276251793
# batches 0-13 done
# beta = 1
#
# iteration 122 train_acc 1.0 test_acc 0.846500039100647 train_mse 0.008767555467784405
# batches 0-13 done
# beta = 1
#
# iteration 123 train_acc 1.0 test_acc 0.8470000624656677 train_mse 0.008506948128342628
# batches 0-13 done
# beta = 1
#
# iteration 124 train_acc 1.0 test_acc 0.8470000624656677 train_mse 0.008252914994955063
# batches 0-13 done
# beta = 1
#
# iteration 125 train_acc 1.0 test_acc 0.846500039100647 train_mse 0.008005829527974129
# batches 0-13 done
# beta = 1
#
# iteration 126 train_acc 1.0 test_acc 0.8475000262260437 train_mse 0.007768568117171526
# batches 0-13 done
# beta = 1
#
# iteration 127 train_acc 1.0 test_acc 0.8470000624656677 train_mse 0.007534670643508434
# batches 0-13 done
# beta = 1
#
# iteration 128 train_acc 1.0000 test_acc 0.8470 train_mse 0.007311154960142827
# CPU times: user 50min 14s, sys: 20min 19s, total: 1h 10min 33s
# Wall time: 1h 6min 23s
