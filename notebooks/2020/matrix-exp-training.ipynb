# %%
import sys
sys.path.append("../src")

# %%
# %load_ext autoreload

# %%
# %autoreload 2

import sys
import numpy as np
from PIL import Image

import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import transforms, datasets
from torchvision.datasets import FashionMNIST

import matplotlib.pyplot as plt
from pytorch_impl.nns import FCN
from pytorch_impl.nns.utils import warm_up_batch_norm, to_one_hot
from pytorch_impl.estimators import MatrixExpEstimator, GradientBoostingEstimator
from pytorch_impl import ClassifierTraining
from pytorch_impl.matrix_exp import matrix_exp, compute_exp_term

# %%
torch.manual_seed(0)

num_classes = 10

if torch.cuda.is_available() and False:
    device = torch.device('cuda:0')
else:
    device = torch.device('cpu')

print('Torch version: {}'.format(torch.__version__))
print('Device: {}'.format(device))

train_loader = torch.utils.data.DataLoader(
    FashionMNIST(root='.', train=True, download=True,
          transform=transforms.ToTensor()),
    batch_size=32, shuffle=True, pin_memory=True)

test_loader = torch.utils.data.DataLoader(
    FashionMNIST(root='.', train=False, transform=transforms.ToTensor()),
    batch_size=32, shuffle=True, pin_memory=True)

device
# Out:
# Torch version: 1.3.1
# Device: cpu
# device(type='cpu')

# %%
a = 30 / 180 * np.pi
M = torch.tensor([[0, -1], [1, 0]]) * a
matrix_exp(M, device).cpu().numpy()
# Out:
# array([[ 0.8660254, -0.5      ],
#        [ 0.5      ,  0.8660254]], dtype=float32)

# %%
a = 30 / 180 * np.pi
M = torch.tensor([[0, -1], [1, 0]]) * a
M_clone = M.clone().to(device)
(torch.matmul(M_clone, compute_exp_term(M, device)) + torch.eye(2)).numpy()
# Out:
# array([[ 0.8660254, -0.5      ],
#        [ 0.5      ,  0.8660254]], dtype=float32)

# %%
D = 28

model     = FCN(10, D * D).to(device)

# %%
base_estimator = MatrixExpEstimator(model, num_classes, device, learning_rate=1., aug_grad=True)

_, (X, y) = next(enumerate(train_loader))
base_estimator.fit_batch(X, y)
gb_estimator = GradientBoostingEstimator(base_estimator, num_classes, nn.CrossEntropyLoss(), device)
# Out:
# aug_c 0.3742941915988922
# accuracy before fit 0.09375, loss 1.04214
# computing grads ...
# exponentiating kernel matrix ...
# fitting done. took 1s

# %%
n_iter = 100

for batch_id in range(100):
    _, (X, y) = next(enumerate(train_loader))
    X, y = X.to(device), y.to(device)

    if batch_id % (n_iter // 10) == 0:
        gb_estimator.step()
        print(gb_estimator.predict(X)[:5])
    
    gb_estimator.fit_batch(X, y)
    print()
    print()
# Out:
# tensor([[-1.3116, -1.3073, -1.6780, -0.8270,  0.5999, -1.4074, -1.2200, -1.2811,
#          -1.5010, -1.5031],
#         [-0.9381, -0.2929, -1.0449, -0.0203, -0.9594, -1.2553, -1.6095, -0.9632,
#          -1.1724, -1.1886],
#         [-1.1686, -1.4108, -0.9120, -0.7105, -1.1318, -0.9942, -1.2031, -1.1310,
#          -1.5252, -0.1785],
#         [-1.0273,  0.6424, -0.8892, -0.7680, -0.7968, -1.3836, -1.5088, -0.9488,
#          -1.0229, -1.1342],
#         [-0.1427, -0.5453, -1.5399, -0.6621, -0.6578, -1.3688, -0.8946, -1.1529,
#          -1.2402, -1.0434]])
# accuracy before fit 0.56250, loss 1.70072
# computing grads ...
# exponentiating kernel matrix ...
# current beta 3.139465808868408
# fitting done. took 2s
#
#
#
# accuracy before fit 0.50000, loss 1.77643
# computing grads ...
# exponentiating kernel matrix ...
# current beta 3.0946052074432373
# fitting done. took 1s
#
#
#
# accuracy before fit 0.65625, loss 1.61806
# computing grads ...
# exponentiating kernel matrix ...
# current beta 3.202892303466797
# fitting done. took 1s
#
#
#
# accuracy before fit 0.68750, loss 1.57556
# computing grads ...
# exponentiating kernel matrix ...
# current beta 3.211136817932129
# fitting done. took 1s
#
#
#
# accuracy before fit 0.59375, loss 1.75887
# computing grads ...
# exponentiating kernel matrix ...
# current beta 3.1125564575195312
# fitting done. took 1s
#
#
#
# accuracy before fit 0.65625, loss 1.63504
# computing grads ...
# exponentiating kernel matrix ...
# current beta 3.185920238494873
# fitting done. took 1s
#
#
#
# accuracy before fit 0.46875, loss 1.76041
# computing grads ...
# exponentiating kernel matrix ...
# current beta 3.1179652214050293
# fitting done. took 1s
#
#
#
# accuracy before fit 0.43750, loss 1.74228
# computing grads ...
# exponentiating kernel matrix ...
# current beta 3.10353684425354
# fitting done. took 1s
#
#
#
# accuracy before fit 0.68750, loss 1.75984
# computing grads ...
# exponentiating kernel matrix ...
# current beta 3.1380903720855713
# fitting done. took 1s
#
#
#
# accuracy before fit 0.53125, loss 1.71716
# computing grads ...
# exponentiating kernel matrix ...
# current beta 3.143784761428833
# fitting done. took 1s
#
#
#
# beta 3.144995403289795
# tensor([[-0.4983,  0.7910, -0.6586,  0.0723, -0.7285, -0.7578, -0.9547, -0.9006,
#          -1.1652, -0.9898],
#         [-1.1099,  3.4978, -1.1644, -1.1871, -1.4505, -1.8735, -1.5283, -1.3489,
#          -1.6428, -1.3948],
#         [ 0.6943, -0.3335, -1.7172,  0.5819, -1.1302, -2.0765, -0.7690, -1.4438,
#          -1.6053, -1.6774],
#         [-1.4346, -1.3334, -1.2791, -1.2562, -1.0213, -0.4266, -1.3860, -1.0658,
#          -0.9388,  2.4778],
#         [-1.6457, -1.6825, -1.5902, -1.5657, -1.6678, -0.4629, -1.5834,  2.1847,
#          -1.4300, -0.2565]])
# accuracy before fit 0.56250, loss 1.21901
# computing grads ...
# exponentiating kernel matrix ...
# current beta 2.9159605503082275
# fitting done. took 1s
#
#
#
# accuracy before fit 0.65625, loss 1.29052
# computing grads ...
# exponentiating kernel matrix ...
# current beta 2.940314292907715
# fitting done. took 2s
#
#
#
# accuracy before fit 0.68750, loss 1.05519
# computing grads ...
# exponentiating kernel matrix ...
# current beta 2.9546422958374023
# fitting done. took 2s
#
#
#
# accuracy before fit 0.71875, loss 0.99341
# computing grads ...
# exponentiating kernel matrix ...
# current beta 2.9813473224639893
# fitting done. took 1s
#
#
#
# accuracy before fit 0.71875, loss 1.09031
# computing grads ...
# exponentiating kernel matrix ...
# current beta 3.0015878677368164
# fitting done. took 1s
#
#
#
# accuracy before fit 0.75000, loss 0.89749
# computing grads ...
# exponentiating kernel matrix ...
# current beta 2.8500680923461914
# fitting done. took 2s
#
#
#
# accuracy before fit 0.62500, loss 1.18428
# computing grads ...
# exponentiating kernel matrix ...
# current beta 2.9600467681884766
# fitting done. took 1s
#
#
#
# accuracy before fit 0.62500, loss 1.31239
# computing grads ...
# exponentiating kernel matrix ...
# current beta 2.9563679695129395
# fitting done. took 1s
#
#
#
# accuracy before fit 0.65625, loss 1.12460
# computing grads ...
# exponentiating kernel matrix ...
# current beta 2.9310221672058105
# fitting done. took 2s
#
#
#
# accuracy before fit 0.59375, loss 1.30113
# computing grads ...
# exponentiating kernel matrix ...
# current beta 2.907555103302002
# fitting done. took 2s
#
#
#
# beta 2.939891242980957
# tensor([[-2.1806, -1.8918,  1.4393, -2.1630,  2.0987, -1.7581, -0.2344, -2.0036,
#          -1.0208, -1.4672],
#         [-0.6218,  1.9104, -1.1932,  0.2344, -0.6274, -1.5941, -1.4020, -1.0611,
#          -1.7406, -0.9838],
#         [ 1.5494, -0.9138, -0.4202, -0.0284, -1.1223, -0.9425, -0.2441, -1.5177,
#          -1.2234, -0.7845],
#         [ 1.4498, -1.3020, -0.3934, -1.0283, -1.3086, -1.6024,  0.0225, -1.3168,
#          -0.9873, -1.3300],
#         [-1.5335, -1.7884, -1.5339, -1.7073, -1.4458, -0.6310, -1.4829,  0.4816,
#          -1.2227,  2.4175]])
# accuracy before fit 0.71875, loss 0.98490
# computing grads ...
# exponentiating kernel matrix ...
# current beta 2.806180238723755
# fitting done. took 2s
#
#
#
# accuracy before fit 0.78125, loss 0.74889
# computing grads ...
# exponentiating kernel matrix ...
# current beta 2.6198360919952393
# fitting done. took 2s
#
#
#
# accuracy before fit 0.75000, loss 0.86557
# computing grads ...
# exponentiating kernel matrix ...
# current beta 2.714280605316162
# fitting done. took 2s
#
#
#
# accuracy before fit 0.81250, loss 0.76792
# computing grads ...
# exponentiating kernel matrix ...
# current beta 2.6258225440979004
# fitting done. took 1s
#
#
#
# accuracy before fit 0.81250, loss 0.77749
# computing grads ...
# exponentiating kernel matrix ...
# current beta 2.6487390995025635
# fitting done. took 2s
#
#
#
# accuracy before fit 0.65625, loss 1.02630
# computing grads ...
# exponentiating kernel matrix ...
# current beta 2.8952536582946777
# fitting done. took 1s
#
#
#
# accuracy before fit 0.71875, loss 0.99191
# computing grads ...
# exponentiating kernel matrix ...
# current beta 2.882338047027588
# fitting done. took 1s
#
#
#
# accuracy before fit 0.81250, loss 0.78094
# computing grads ...
# exponentiating kernel matrix ...
# current beta 2.6716763973236084
# fitting done. took 1s
#
#
#
# accuracy before fit 0.81250, loss 0.74752
# computing grads ...
# exponentiating kernel matrix ...
# current beta 2.616332530975342
# fitting done. took 1s
#
#
#
# accuracy before fit 0.81250, loss 0.72138
# computing grads ...
# exponentiating kernel matrix ...
# current beta 2.4716596603393555
# fitting done. took 1s
#
#
#
# beta 2.695211887359619
# tensor([[ 1.2161, -0.7444, -1.1483, -0.2615, -1.1938, -0.9449,  0.2173, -1.5311,
#          -0.6293, -1.1429],
#         [-0.6267, -1.3943, -0.2722, -0.1085,  0.0310, -1.4417,  0.3377, -1.8712,
#          -1.0233, -1.7376],
#         [-1.1197, -1.3915,  0.7784, -1.8341,  1.3815, -1.7192,  0.2192, -1.4403,
#          -1.3972, -1.5152],
#         [ 2.4387, -1.5394, -0.8841,  0.3473, -1.9270, -2.1076,  0.2059, -1.9864,
#          -2.1247, -1.7639],
#         [ 1.0100, -1.5721,  0.5827, -1.0230, -1.2109, -1.1152,  0.4626, -1.8248,
#          -1.1583, -1.2995]])
# accuracy before fit 0.68750, loss 0.97443
# computing grads ...
# exponentiating kernel matrix ...
# current beta 2.761577844619751
# fitting done. took 1s
#
#
#
# accuracy before fit 0.81250, loss 0.74148
# computing grads ...
# exponentiating kernel matrix ...
# current beta 2.593161106109619
# fitting done. took 1s
#
#
#
# accuracy before fit 0.68750, loss 0.87279
# computing grads ...
# exponentiating kernel matrix ...
# current beta 2.7331817150115967
# fitting done. took 1s
#
#
#
# accuracy before fit 0.65625, loss 1.04887
# computing grads ...
# exponentiating kernel matrix ...
# current beta 2.7329161167144775
# fitting done. took 1s
#
#
#
# accuracy before fit 0.71875, loss 0.92614
# computing grads ...
# exponentiating kernel matrix ...
# current beta 2.748364210128784
# fitting done. took 1s
#
#
#
# accuracy before fit 0.90625, loss 0.71474
# computing grads ...
# exponentiating kernel matrix ...
# current beta 2.487528085708618
# fitting done. took 1s
#
#
#
# accuracy before fit 0.84375, loss 0.77470
# computing grads ...
# exponentiating kernel matrix ...
# current beta 2.6337552070617676
# fitting done. took 1s
#
#
#
# accuracy before fit 0.78125, loss 0.86778
# computing grads ...
# exponentiating kernel matrix ...
# current beta 2.7692360877990723
# fitting done. took 1s
#
#
#
# accuracy before fit 0.71875, loss 0.89338
# computing grads ...
# exponentiating kernel matrix ...
# current beta 2.658046245574951
# fitting done. took 1s
#
#
#
# accuracy before fit 0.81250, loss 0.93078
# computing grads ...
# exponentiating kernel matrix ...
# current beta 2.7441210746765137
# fitting done. took 1s
#
#
#
# beta 2.6861887693405153
# tensor([[-1.4641e+00,  3.8098e+00, -8.5554e-01,  2.9257e-04, -6.9992e-01,
#          -1.3633e+00, -1.7885e+00, -1.2359e+00, -1.7003e+00, -1.7156e+00],
#         [-1.0551e+00,  3.4529e+00, -1.1134e+00, -8.0081e-01, -1.3327e+00,
#          -1.2288e+00, -1.5632e+00, -1.3226e+00, -1.0788e+00, -1.7038e+00],
#         [-1.8779e+00, -1.4104e+00, -1.7986e+00, -1.6724e+00, -1.5651e+00,
#           3.5635e-01, -1.6781e+00,  4.0651e+00, -1.0043e+00, -1.5028e+00],
#         [-3.3519e-01, -1.5779e+00,  2.3778e+00, -2.5399e+00, -8.2241e-01,
#          -2.0318e+00,  5.9038e-01, -2.0567e+00, -1.3114e+00, -1.8934e+00],
#         [ 1.7672e-02, -8.5219e-01, -9.0522e-01, -1.1705e+00, -1.4809e+00,
#           1.8428e+00, -6.3302e-01, -7.8500e-01, -3.7198e-01,  1.2994e-01]])
# accuracy before fit 0.75000, loss 0.76981
# computing grads ...
# exponentiating kernel matrix ...
# current beta 2.6003668308258057
# fitting done. took 1s
#
#
#
# accuracy before fit 0.81250, loss 0.88420
# computing grads ...
# exponentiating kernel matrix ...
# current beta 2.7645413875579834
# fitting done. took 1s
#
#
#
# accuracy before fit 0.78125, loss 0.79181
# computing grads ...
# exponentiating kernel matrix ...
# current beta 2.605126142501831
# fitting done. took 2s
#
#
#
# accuracy before fit 0.78125, loss 0.68803
# computing grads ...
# exponentiating kernel matrix ...
# current beta 2.4991564750671387
# fitting done. took 1s
#
#
#
# accuracy before fit 0.71875, loss 0.87477
# computing grads ...
# exponentiating kernel matrix ...
# current beta 2.6271488666534424
# fitting done. took 1s
#
#
#
# accuracy before fit 0.84375, loss 0.66065
# computing grads ...
# exponentiating kernel matrix ...
# current beta 2.3972082138061523
# fitting done. took 1s
#
#
#
# accuracy before fit 0.87500, loss 0.63978
# computing grads ...
# exponentiating kernel matrix ...
# current beta 2.433635950088501
# fitting done. took 1s
#
#
#
# accuracy before fit 0.87500, loss 0.55573
# computing grads ...
# exponentiating kernel matrix ...
# current beta 1.9918057918548584
# fitting done. took 1s
#
#
#
# accuracy before fit 0.84375, loss 0.54867
# computing grads ...
# exponentiating kernel matrix ...
# current beta 1.960264801979065
# fitting done. took 1s
#
#
#
# accuracy before fit 0.81250, loss 0.75622
# computing grads ...
# exponentiating kernel matrix ...
# current beta 2.6181652545928955
# fitting done. took 1s
#
#
#
# beta 2.4497419714927675
# tensor([[-0.6154, -0.9592,  0.6220, -1.1926,  0.6542, -1.0724, -0.1515, -1.7053,
#          -1.1047, -1.6554],
#         [-1.6949, -1.4301, -1.3868, -1.4659, -1.5161,  1.7199, -1.2499,  1.5771,
#          -1.2012, -0.9593],
#         [-0.2778, -0.9805, -0.8924,  0.9354, -0.7350, -0.7571,  0.0537, -0.9904,
#          -1.4739, -1.2145],
#         [-1.4490,  3.5732, -1.0773,  0.3642, -0.6047, -1.5565, -1.6472, -1.3003,
#          -1.7943, -1.3726],
#         [-1.1178, -2.3752,  0.1999, -0.9657, -0.2683, -1.7683,  2.4927, -2.1959,
#          -1.3992, -2.2636]])
# accuracy before fit 0.75000, loss 0.84100
# computing grads ...
# exponentiating kernel matrix ...
# current beta 2.6173813343048096
# fitting done. took 1s
#
#
#
# accuracy before fit 0.87500, loss 0.52029
# computing grads ...
# exponentiating kernel matrix ...
# current beta 1.8443830013275146
# fitting done. took 1s
#
#
#
# accuracy before fit 0.78125, loss 0.71561
# computing grads ...
# exponentiating kernel matrix ...
# current beta 2.4949796199798584
# fitting done. took 2s
#
#
#
# accuracy before fit 0.78125, loss 0.82814
# computing grads ...
# exponentiating kernel matrix ...
# current beta 2.645284652709961
# fitting done. took 2s
#
#
#
# accuracy before fit 0.65625, loss 0.85006
# computing grads ...
# exponentiating kernel matrix ...
# current beta 2.5894722938537598
# fitting done. took 2s
#
#
#
# accuracy before fit 0.71875, loss 0.79399
# computing grads ...
# exponentiating kernel matrix ...
# current beta 2.6133172512054443
# fitting done. took 2s
#
#
#
# accuracy before fit 0.81250, loss 0.67165
# computing grads ...
# exponentiating kernel matrix ...
# current beta 2.480172634124756
# fitting done. took 1s
#
#
#
# accuracy before fit 0.90625, loss 0.59041
# computing grads ...
# exponentiating kernel matrix ...
# current beta 2.1431643962860107
# fitting done. took 1s
#
#
#
# accuracy before fit 0.84375, loss 0.65886
# computing grads ...
# exponentiating kernel matrix ...
# current beta 2.462658166885376
# fitting done. took 2s
#
#
#
# accuracy before fit 0.71875, loss 0.84995
# computing grads ...
# exponentiating kernel matrix ...
# current beta 2.753337860107422
# fitting done. took 2s
#
#
#
# beta 2.464415121078491
# tensor([[-1.6661, -1.4831, -1.5363, -1.5354, -1.1827,  0.4827, -1.3276,  2.6662,
#          -1.1531, -0.6114],
#         [-1.1870, -0.9471, -0.8891, -1.4289, -0.9149,  2.0236, -0.6955, -0.1198,
#          -0.9330, -1.0150],
#         [-2.4766, -2.5515, -2.6702, -2.5517, -2.3934,  0.3391, -2.5985,  2.0927,
#          -1.7541,  2.5223],
#         [-2.0502, -2.4606, -0.3392, -1.6213,  0.8671, -2.0374,  2.8008, -2.1117,
#          -1.6087, -1.9167],
#         [-1.4467, -1.6299,  3.1554, -2.1984,  0.7994, -1.9837,  0.2734, -1.6476,
#          -2.3790, -1.4271]])
# accuracy before fit 0.65625, loss 0.93953
# computing grads ...
# exponentiating kernel matrix ...
# current beta 2.449079990386963
# fitting done. took 1s
#
#
#
# accuracy before fit 0.84375, loss 0.52069
# computing grads ...
# exponentiating kernel matrix ...
# current beta 2.2175331115722656
# fitting done. took 1s
#
#
#
# accuracy before fit 0.84375, loss 0.57570
# computing grads ...
# exponentiating kernel matrix ...
# current beta 2.1795907020568848
# fitting done. took 1s
#
#
#
# accuracy before fit 0.78125, loss 0.67026
# computing grads ...
# exponentiating kernel matrix ...
# current beta 2.374014377593994
# fitting done. took 1s
#
#
#
# accuracy before fit 0.81250, loss 0.70250
# computing grads ...
# exponentiating kernel matrix ...
# current beta 2.5302226543426514
# fitting done. took 1s
#
#
#
# accuracy before fit 0.87500, loss 0.54877
# computing grads ...
# exponentiating kernel matrix ...
# current beta 2.24906325340271
# fitting done. took 1s
#
#
#
# accuracy before fit 0.62500, loss 0.84737
# computing grads ...
# exponentiating kernel matrix ...
# current beta 2.3750741481781006
# fitting done. took 1s
#
#
#
# accuracy before fit 0.75000, loss 0.91649
# computing grads ...
# exponentiating kernel matrix ...
# current beta 2.6422512531280518
# fitting done. took 1s
#
#
#
# accuracy before fit 0.78125, loss 0.60915
# computing grads ...
# exponentiating kernel matrix ...
# current beta 2.3802638053894043
# fitting done. took 1s
#
#
#
# accuracy before fit 0.84375, loss 0.51693
# computing grads ...
# exponentiating kernel matrix ...
# current beta 2.073928117752075
# fitting done. took 1s
#
#
#
# beta 2.34710214138031
# tensor([[-1.7510e+00, -1.5223e+00, -1.6295e+00, -1.4800e+00, -1.7577e+00,
#           1.1780e+00, -1.5499e+00,  2.9093e+00, -1.1650e+00, -8.8588e-01],
#         [-2.6674e+00, -2.3085e+00, -2.1265e+00, -2.2127e+00, -1.7807e+00,
#          -1.4630e-03, -2.4835e+00,  2.4156e-01, -6.6720e-01,  3.6316e+00],
#         [-1.1836e+00,  3.1515e+00, -1.1315e+00, -1.0641e-01, -4.5772e-01,
#          -1.1116e+00, -1.2332e+00, -1.1005e+00, -1.7333e+00, -1.1555e+00],
#         [-1.4949e+00, -1.3397e+00, -1.7136e+00, -1.5349e+00, -1.2206e+00,
#          -7.4898e-03, -1.7125e+00,  3.9620e+00, -1.3860e+00, -5.6946e-01],
#         [-9.7079e-01, -1.1961e+00, -1.7216e+00, -1.2785e+00, -1.3198e+00,
#           1.3393e+00, -1.4827e+00, -3.2103e-01, -7.5565e-01, -1.5638e-02]])
# accuracy before fit 0.90625, loss 0.49922
# computing grads ...
# exponentiating kernel matrix ...
# current beta 2.1466779708862305
# fitting done. took 1s
#
#
#
# accuracy before fit 0.81250, loss 0.61445
# computing grads ...
# exponentiating kernel matrix ...
# current beta 2.3399505615234375
# fitting done. took 1s
#
#
#
# accuracy before fit 0.68750, loss 0.76169
# computing grads ...
# exponentiating kernel matrix ...
# current beta 2.422210454940796
# fitting done. took 1s
#
#
#
# accuracy before fit 0.90625, loss 0.43740
# computing grads ...
# exponentiating kernel matrix ...
# current beta 1.8330883979797363
# fitting done. took 1s
#
#
#
# accuracy before fit 0.90625, loss 0.49309
# computing grads ...
# exponentiating kernel matrix ...
# current beta 2.0667572021484375
# fitting done. took 1s
#
#
#
# accuracy before fit 0.87500, loss 0.53434
# computing grads ...
# exponentiating kernel matrix ...
# current beta 2.2341558933258057
# fitting done. took 2s
# accuracy before fit 0.90625, loss 0.55294
# computing grads ...
# exponentiating kernel matrix ...
# current beta 2.261086940765381
# fitting done. took 2s
#
#
#
# accuracy before fit 0.78125, loss 0.62255
# computing grads ...
# exponentiating kernel matrix ...
# current beta 2.3446102142333984
# fitting done. took 1s
#
#
#
# accuracy before fit 0.78125, loss 0.64513
# computing grads ...
# exponentiating kernel matrix ...
# current beta 2.3759281635284424
# fitting done. took 1s
#
#
#
# accuracy before fit 0.71875, loss 0.99092
# computing grads ...
# exponentiating kernel matrix ...
# current beta 2.49845027923584
# fitting done. took 1s
#
#
#
# beta 2.2522916078567503
# tensor([[-0.9732, -0.9867, -1.2511, -0.7503, -1.3648,  2.1495, -1.1402, -0.6771,
#          -0.5742, -0.0868],
#         [-1.1668,  3.8514, -1.5034, -0.1144, -0.8765, -1.1748, -1.6132, -1.6199,
#          -0.9702, -1.7498],
#         [-0.1367, -1.5708,  0.2192, -0.9399,  0.0210, -0.4636,  1.6568, -1.7840,
#          -0.5221, -2.5885],
#         [-1.5234, -2.4036, -1.4229,  0.1246,  2.1810, -2.1724,  0.9951, -2.2303,
#          -1.4338, -1.6352],
#         [-0.6115,  0.2032, -1.0435,  3.2466, -0.6415, -2.2971, -1.6276, -2.5804,
#          -2.0973, -1.9850]])
# accuracy before fit 0.71875, loss 0.82982
# computing grads ...
# exponentiating kernel matrix ...
# current beta 2.3558919429779053
# fitting done. took 1s
#
#
#
# accuracy before fit 0.71875, loss 0.94425
# computing grads ...
# exponentiating kernel matrix ...
# current beta 2.4000463485717773
# fitting done. took 2s
#
#
#
# accuracy before fit 0.65625, loss 0.91947
# computing grads ...
# exponentiating kernel matrix ...
# current beta 2.421971082687378
# fitting done. took 1s
#
#
#
# accuracy before fit 0.81250, loss 0.56915
# computing grads ...
# exponentiating kernel matrix ...
# current beta 2.287269115447998
# fitting done. took 1s
#
#
#
# accuracy before fit 0.84375, loss 0.64834
# computing grads ...
# exponentiating kernel matrix ...
# current beta 2.4716954231262207
# fitting done. took 1s
#
#
#
# accuracy before fit 0.78125, loss 0.61380
# computing grads ...
# exponentiating kernel matrix ...
# current beta 2.384047746658325
# fitting done. took 1s
#
#
#
# accuracy before fit 0.81250, loss 0.64511
# computing grads ...
# exponentiating kernel matrix ...
# current beta 2.3853869438171387
# fitting done. took 1s
#
#
#
# accuracy before fit 0.78125, loss 0.66803
# computing grads ...
# exponentiating kernel matrix ...
# current beta 2.2322065830230713
# fitting done. took 1s
#
#
#
# accuracy before fit 0.84375, loss 0.53582
# computing grads ...
# exponentiating kernel matrix ...
# current beta 2.229116201400757
# fitting done. took 1s
#
#
#
# accuracy before fit 0.75000, loss 0.98711
# computing grads ...
# exponentiating kernel matrix ...
# current beta 2.3516037464141846
# fitting done. took 1s
#
#
#
# beta 2.3519235134124754
# tensor([[-2.4916, -2.3408,  0.7949, -2.3371,  3.2809, -2.4546,  1.6382, -2.3982,
#          -1.7027, -1.9401],
#         [ 1.6414, -0.8657, -1.4407,  0.4186, -0.4051, -2.4915,  0.5199, -1.9110,
#          -1.9537, -1.7871],
#         [-0.6700, -2.0843, -1.3421, -0.1821, -1.9609,  1.7509, -0.9235, -1.6076,
#          -1.1391,  0.0863],
#         [-0.7603, -1.7689,  0.7919, -1.9618,  1.3327, -1.7509,  1.5644, -1.9601,
#          -1.2004, -2.4712],
#         [ 0.0647, -0.1787, -1.7995,  2.1403, -0.4435, -1.9560, -0.5443, -2.2724,
#          -1.5740, -1.8571]])
# accuracy before fit 0.78125, loss 0.71540
# computing grads ...
# exponentiating kernel matrix ...
# current beta 2.453726291656494
# fitting done. took 2s
#
#
#
# accuracy before fit 0.84375, loss 0.53025
# computing grads ...
# exponentiating kernel matrix ...
# current beta 2.2679357528686523
# fitting done. took 1s
#
#
#
# accuracy before fit 0.84375, loss 0.48216
# computing grads ...
# exponentiating kernel matrix ...
# current beta 2.11214017868042
# fitting done. took 1s
#
#
#
# accuracy before fit 0.75000, loss 0.77314
# computing grads ...
# exponentiating kernel matrix ...
# current beta 2.5226223468780518
# fitting done. took 1s
#
#
#
# accuracy before fit 0.87500, loss 0.56482
# computing grads ...
# exponentiating kernel matrix ...
# current beta 2.3042092323303223
# fitting done. took 1s
#
#
#
# accuracy before fit 0.87500, loss 0.41609
# computing grads ...
# exponentiating kernel matrix ...
# current beta 1.9065574407577515
# fitting done. took 1s
#
#
#
# accuracy before fit 0.71875, loss 0.79949
# computing grads ...
# exponentiating kernel matrix ...
# current beta 2.6032276153564453
# fitting done. took 1s
#
#
#
# accuracy before fit 0.78125, loss 0.61992
# computing grads ...
# exponentiating kernel matrix ...
# current beta 2.350806951522827
# fitting done. took 1s
#
#
#
# accuracy before fit 0.81250, loss 0.56147
# computing grads ...
# exponentiating kernel matrix ...
# current beta 2.276350498199463
# fitting done. took 1s
#
#
#
# accuracy before fit 0.84375, loss 0.49768
# computing grads ...
# exponentiating kernel matrix ...
# current beta 2.1666576862335205
# fitting done. took 1s
